# %%
# Roberto de Brito
# RA: 2025204957
# O programa deve pedir o peso e a altura do usuário. [Dica: usar float]
# O programa deve calcular o IMC com base na fórmula.
# O programa deve informar se o IMC está dentro de uma faixa saudável, de acordo com a tabela abaixo:
# 1. Abaixo de 18.5: Abaixo do peso.
# 2. 18.5 a 24.9: Peso saudável.
# 3. 25 a 29.9: Sobrepeso.
# 4. Acima de 30: Obesidade.
# E não menos importante: tente resolver sem usar IA generativa como o ChatGPT. Mais do que ganhar pontos, o que realmente importa é aprender — mesmo que seja errando.

Peso = 0.0
Altura = 0.0
imc = 0
while Peso <= 0 or Altura <= 0:
   Altura = 1.98 # @param {type:"number"}
   Peso = 130 # @param {type:"number"}
else:
  imc = round(float (Peso / (Altura ** 2)),3)
  if imc >= 30:
      print(f"Seu IMC = {imc}, conforme a Organização Mundial da Saúde (OMS), seu peso {peso}kg e altura {altura}m, recebe classificação: Obesidade")
  elif imc >= 25:
      print(f"Seu IMC = {imc}, conforme a Organização Mundial da Saúde (OMS), seu peso {peso}kg e altura {altura}m, recebe classificação: Sobrepeso")
  elif imc >= 18.5:
      print(f"Seu IMC = {imc}, conforme a Organização Mundial da Saúde (OMS), seu peso {peso}kg e altura {altura}m, recebe classificação: Peso saudável")
  else:
      print(f"Seu IMC = {imc}, conforme a Organização Mundial da Saúde (OMS), seu peso {peso}kg e altura {altura}m, recebe classificação: Abaixo do peso")
# Out:
# Seu IMC = 33.16, conforme a Organização Mundial da Saúde (OMS), seu peso 87.5kg e altura 1.8m, recebe classificação: Obesidade
